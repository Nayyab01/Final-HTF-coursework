# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yfinance in c:\users\nayab\appdata\roaming\python\python39\site-packages (0.2.3)
# Requirement already satisfied: pandas>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\nayab\appdata\roaming\python\python39\site-packages (from yfinance) (1.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\nayab\appdata\roaming\python\python39\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\nayab\appdata\roaming\python\python39\site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\nayab\appdata\roaming\python\python39\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: requests>=2.26 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\nayab\appdata\roaming\python\python39\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: cryptography>=3.3.2 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (3.4.8)
# Requirement already satisfied: numpy>=1.16.5 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\programdata\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
BTC = yf.download('BTC-USD', start='2022-12-28', end='2022-12-29',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
BTC
# Out:
#                              Open          High           Low         Close  \
# Datetime
# 2022-12-28 00:00:00  16716.400391  16716.400391  16716.400391  16716.400391
# 2022-12-28 00:01:00  16716.486328  16716.486328  16716.486328  16716.486328
# 2022-12-28 00:02:00  16715.480469  16715.480469  16715.480469  16715.480469
# 2022-12-28 00:03:00  16714.017578  16714.017578  16714.017578  16714.017578
# 2022-12-28 00:04:00  16716.972656  16716.972656  16716.972656  16716.972656
# ...                           ...           ...           ...           ...
# 2022-12-28 23:54:00  16547.451172  16547.451172  16547.451172  16547.451172
# 2022-12-28 23:55:00  16548.355469  16548.355469  16548.355469  16548.355469
# 2022-12-28 23:56:00  16548.394531  16548.394531  16548.394531  16548.394531
# 2022-12-28 23:57:00  16549.785156  16549.785156  16549.785156  16549.785156
# 2022-12-28 23:58:00  16550.255859  16550.255859  16550.255859  16550.255859
#
#                         Adj Close   Volume
# Datetime
# 2022-12-28 00:00:00  16716.400391        0
# 2022-12-28 00:01:00  16716.486328        0
# 2022-12-28 00:02:00  16715.480469        0
# 2022-12-28 00:03:00  16714.017578        0
# 2022-12-28 00:04:00  16716.972656        0
# ...                           ...      ...
# 2022-12-28 23:54:00  16547.451172  1022976
# 2022-12-28 23:55:00  16548.355469  2757632
# 2022-12-28 23:56:00  16548.394531  1175552
# 2022-12-28 23:57:00  16549.785156  1025024
# 2022-12-28 23:58:00  16550.255859        0
#
# [1435 rows x 6 columns]

# %%
ETH = yf.download('ETH-USD', start='2022-12-28', end='2022-12-29',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ETH
# Out:
#                             Open         High          Low        Close  \
# Datetime
# 2022-12-28 00:00:00  1212.736572  1212.736572  1212.736572  1212.736572
# 2022-12-28 00:01:00  1212.768066  1212.768066  1212.768066  1212.768066
# 2022-12-28 00:02:00  1212.663208  1212.663208  1212.663208  1212.663208
# 2022-12-28 00:03:00  1212.757812  1212.757812  1212.757812  1212.757812
# 2022-12-28 00:04:00  1212.963379  1212.963379  1212.963379  1212.963379
# ...                          ...          ...          ...          ...
# 2022-12-28 23:54:00  1188.976685  1188.976685  1188.976685  1188.976685
# 2022-12-28 23:55:00  1189.352295  1189.352295  1189.352295  1189.352295
# 2022-12-28 23:56:00  1189.535767  1189.535767  1189.535767  1189.535767
# 2022-12-28 23:57:00  1189.690918  1189.690918  1189.690918  1189.690918
# 2022-12-28 23:58:00  1190.018066  1190.018066  1190.018066  1190.018066
#
#                        Adj Close   Volume
# Datetime
# 2022-12-28 00:00:00  1212.736572        0
# 2022-12-28 00:01:00  1212.768066        0
# 2022-12-28 00:02:00  1212.663208        0
# 2022-12-28 00:03:00  1212.757812        0
# 2022-12-28 00:04:00  1212.963379        0
# ...                          ...      ...
# 2022-12-28 23:54:00  1188.976685   904192
# 2022-12-28 23:55:00  1189.352295  1958912
# 2022-12-28 23:56:00  1189.535767  3775488
# 2022-12-28 23:57:00  1189.690918  1330176
# 2022-12-28 23:58:00  1190.018066  6927872
#
# [1435 rows x 6 columns]

# %%
S1_0 = BTC['Open'][0]
S2_0 = ETH['Open'][0]

# %%
S1_0
# Out:
# 16716.400390625

# %%
S2_0
# Out:
# 1212.736572265625

# %%
lr1 = np.log(BTC['Adj Close'] / BTC['Adj Close'].shift(1))
lr2 = np.log(ETH['Adj Close'] / ETH['Adj Close'].shift(1))
mu_1 = lr1.mean() * 1440
mu_2 = lr2.mean() * 1440
sigma_1 = lr1.std() * np.sqrt(1440)
sigma_2 = lr2.std() * np.sqrt(1440)
rho = lr1.corr(lr2)
z_0 = 0.00
gamma = 0.5
delta = 1
T = 1
M = len(BTC)

# %%
rho
# Out:
# 0.8698139813517589

# %%
mu_1
# Out:
# -0.010030529224028436

# %%
mu_2
# Out:
# -0.018990072384115333

# %%
sigma_1
# Out:
# 0.007783264099159454

# %%
sigma_2
# Out:
# 0.010117052492744758

# %%
result = linregress(np.log(BTC['Adj Close']), np.log(ETH['Adj Close']))
beta = result.slope

# %%
beta
# Out:
# 1.36010493522342

# %%
dt = T/M
S1 = np.zeros((M + 1, 1))
S2 = np.zeros((M + 1, 1))
z =  np.zeros((M + 1, 1))
a =  np.zeros((M + 1, 1))
b =  np.zeros((M + 1, 1))
c =  np.zeros((M + 1, 1))
Pi_1 = np.zeros((M + 1, 1))
Pi_2 = np.zeros((M + 1, 1))

# %%
tt = np.linspace(0, 1, M + 1)
z[0] = z_0
S1[0] = S1_0
S2[0] = S2_0
sigma_beta = np.sqrt(sigma_1 ** 2 + beta ** 2 * sigma_2 ** 2 + 2 * beta * sigma_1 * sigma_2 * rho)
eta = (-1/delta) * (mu_1 - sigma_1 ** 2/2 + beta*(mu_2 - sigma_2 ** 2/2))
rn = np.random.standard_normal(z.shape)
rn1 = np.random.standard_normal(S1.shape) 
rn2 = np.random.standard_normal(S2.shape) 
for t in range(1, M + 1):
    z[t] = z[t-1]* (1 - delta * (eta - z[t-1])) * dt + sigma_beta * np.sqrt(dt)*((sigma_1 + beta * sigma_2 * rho)/ sigma_beta * rn1[t] + beta * (sigma_2 * np.sqrt(1-rho ** 2)/sigma_beta) * rn1[t]);
    S1[t] = BTC['Adj Close'][t-1]
    S2[t] = ETH['Adj Close'][t-1]

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='BTC')
plt.plot(tt, S2, 'r', lw=1.5, label='ETH')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Stock Price')
# Out:
# Text(0.5, 1.0, 'Stock Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, z, 'g', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Rate')
plt.title('z')
# Out:
# Text(0.5, 1.0, 'z')

# %%
for t in range(1, M + 1):
    a[t] = 0.5 * (T - t * dt)/((1-rho ** 2) * sigma_1 ** 2)
    b[t] = - 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2)/((1 - rho ** 2) * sigma_1 ** 2) - rho * mu_2 * (T - t * dt)/((1 - rho **2) * sigma_1 * sigma_2)
    c[t] = 0.5 * mu_2 ** 2 * (T - t * dt)/((1 - rho ** 2) * sigma_2 ** 2) + 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2 + 2 * sigma_1 * sigma_2 * beta *rho) * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2) + 0.25 * (T - t * dt) ** 2 * mu_2 * delta * rho * (sigma_1 ** 2 + beta * sigma_2 ** 2) + 1/24 * (T - t * dt) ** 3 * (sigma_1 ** 2 + beta * sigma_2 ** 2) ** 2 * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2)
    Pi_1[t] = (1 / S1[t]) * ((mu_1 + delta * z[t])/(gamma * (1 - rho ** 2) * sigma_1 ** 2) + delta/gamma * (-2 * a[t] * (mu_1 + delta * z[t])-b[t]) - rho * mu_2/(gamma * (1 - rho ** 2) * sigma_1 * sigma_2))
    Pi_2[t] = (1 / S2[t]) * (mu_2 / (gamma * (1 - rho ** 2) * sigma_2 ** 2) + delta * beta / gamma * (- 2 * a[t] * (mu_1 + delta * z[t]) - b[t]) - rho * (mu_1 + delta * z[t]) / (gamma * (1 - rho ** 2) * sigma_1 * sigma_2))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1, 'b', lw=1.5, label='w1')
plt.plot(tt, Pi_2, 'r', lw=1.5, label='w2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('%')
plt.title('Weights')
# Out:
# Text(0.5, 1.0, 'Weights')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, - Pi_1 * S1, 'b', lw=1.5, label='Wealth 1')
plt.plot(tt, - Pi_2 * S2, 'r', lw=1.5, label='Wealth 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Cash')
# Out:
# Text(0.5, 1.0, 'Cash')

# %%
Wealth = abs(Pi_1 * S1) + abs(Pi_2 * S2)

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt[1:], Wealth[1:], 'b', lw=1.5, label='Total')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Wealth')
# Out:
# Text(0.5, 1.0, 'Wealth')

# %%
Wealth[1]
# Out:
# array([1159.19440936])

# %%
Wealth[-1]
# Out:
# array([903.16024036])

# %%
(Wealth[-1] - Wealth[1])/Wealth[1]
# Out:
# array([-0.2208725])

# %%
Pi_1.mean()
# Out:
# 0.011053601452600561

# %%
Pi_2.mean()
# Out:
# -0.7152489456097988

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1 + Pi_2 * S2, 'b', lw=1.5, label='Dynamic')
plt.plot(tt, Pi_1.mean() * S1 + Pi_2.mean() * S2, 'r', lw=1.5, label='Static')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Comparison')
# Out:
# Text(0.5, 1.0, 'Comparison')

# %%
S1_0 = 40
S2_0 = 20
mu_1 = 0.01
mu_2 = 0.02
sigma_1 = 0.05
sigma_2 = 0.1
rho = -0.7
z_0 = 0.01
beta = 1
gamma = 0.5
delta = 0.8
T = 1
M = 390

# %%
dt = T/M
S1 = np.zeros((M + 1, 1))
S2 = np.zeros((M + 1, 1))
z =  np.zeros((M + 1, 1))
a =  np.zeros((M + 1, 1))
b =  np.zeros((M + 1, 1))
c =  np.zeros((M + 1, 1))
Pi_1 = np.zeros((M + 1, 1))
Pi_2 = np.zeros((M + 1, 1))

# %%
tt = np.linspace(0, 1, M + 1)
z[0] = z_0
S1[0] = S1_0
S2[0] = S2_0
sigma_beta = np.sqrt(sigma_1 ** 2 + beta ** 2 * sigma_2 ** 2 + 2 * beta * sigma_1 * sigma_2 * rho)
eta = (-1/delta) * (mu_1 - sigma_1 ** 2/2 + beta*(mu_2 - sigma_2 ** 2/2))
rn = np.random.standard_normal(z.shape)
rn1 = np.random.standard_normal(S1.shape) 
rn2 = np.random.standard_normal(S2.shape) 
for t in range(1, M + 1):
    z[t] = z[t-1]* (1 - delta * (eta - z[t-1])) * dt + sigma_beta * np.sqrt(dt)*((sigma_1 + beta * sigma_2 * rho)/ sigma_beta * rn1[t] + beta * (sigma_2 * np.sqrt(1-rho ** 2)/sigma_beta) * rn1[t]);
    S1[t] = S1[t-1] * np.exp((mu_1 + delta * z[t] - sigma_1 ** 2 / 2) * dt + sigma_1 * np.sqrt(dt) * rn1[t])
    S2[t] = S2[t-1] * np.exp((mu_2 - sigma_2 ** 2 / 2) * dt + sigma_2 * np.sqrt(dt) * (rho * rn1[t] + np.sqrt(1 - rho ** 2) * rn2[t]))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='BTC')
plt.plot(tt, S2, 'r', lw=1.5, label='ETH')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Stock Price')
# Out:
# Text(0.5, 1.0, 'Stock Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, z, 'g', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Rate')
plt.title('z')
# Out:
# Text(0.5, 1.0, 'z')

# %%
for t in range(1, M + 1):
    a[t] = 0.5 * (T - t * dt)/((1-rho ** 2) * sigma_1 ** 2)
    b[t] = - 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2)/((1 - rho ** 2) * sigma_1 ** 2) - rho * mu_2 * (T - t * dt)/((1 - rho **2) * sigma_1 * sigma_2)
    c[t] = 0.5 * mu_2 ** 2 * (T - t * dt)/((1 - rho ** 2) * sigma_2 ** 2) + 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2 + 2 * sigma_1 * sigma_2 * beta *rho) * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2) + 0.25 * (T - t * dt) ** 2 * mu_2 * delta * rho * (sigma_1 ** 2 + beta * sigma_2 ** 2) + 1/24 * (T - t * dt) ** 3 * (sigma_1 ** 2 + beta * sigma_2 ** 2) ** 2 * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2)
    Pi_1[t] = (1 / S1[t]) * ((mu_1 + delta * z[t])/(gamma * (1 - rho ** 2) * sigma_1 ** 2) + delta/gamma * (-2 * a[t] * (mu_1 + delta * z[t])-b[t]) - rho * mu_2/(gamma * (1 - rho ** 2) * sigma_1 * sigma_2))
    Pi_2[t] = (1 / S2[t]) * (mu_2 / (gamma * (1 - rho ** 2) * sigma_2 ** 2) + delta * beta / gamma * (- 2 * a[t] * (mu_1 + delta * z[t]) - b[t]) - rho * (mu_1 + delta * z[t]) / (gamma * (1 - rho ** 2) * sigma_1 * sigma_2))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1, 'b', lw=1.5, label='w1')
plt.plot(tt, Pi_2, 'r', lw=1.5, label='w2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('%')
plt.title('Weights')
# Out:
# Text(0.5, 1.0, 'Weights')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1, 'b', lw=1.5, label='Wealth 1')
plt.plot(tt, Pi_2 * S2, 'r', lw=1.5, label='Wealth 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Cash')
# Out:
# Text(0.5, 1.0, 'Cash')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1 + Pi_2 * S2, 'b', lw=1.5, label='Dynamic')
plt.plot(tt, Pi_1.mean() * S1 + Pi_2.mean() * S2, 'r', lw=1.5, label='Static')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Comparison')
# Out:
# Text(0.5, 1.0, 'Comparison')
